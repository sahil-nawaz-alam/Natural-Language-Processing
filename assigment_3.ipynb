# %%
import spacy
from spacy import displacy

# %%
text ="""After a BJP leader and five members of his family were defeated in the municipal council polls in Loha town of Nanded, the Congress said Sunday that voters had given a befitting reply to the saffron party’s “parivarvad politics.”The Bharatiya Janata Party fielded Gajanan Suryawanshi for the Loha mayoral post. His wife, Godavari; brother Sachin Suryawanshi; sister-in-law Supriya Suryavanshi; brother-in-law Yuvraj Waghmare; and nephew’s wife Reena Vyavahare were fielded in different wards of Loha town.The defeat of the six is also being seen as a setback for former chief minister Ashok Chavan, who led the BJP’s campaign in the civic polls. The BJP refused to ask its candidates to withdraw from the fray despite criticism from the Maha Vikas Aghadi over its dynastic politics.“Voters have rejected the BJP’s nepotism. No matter who it fielded for campaigning, the voters did not care. They gave the BJP a taste of its own medicine. What is shocking is that despite widespread criticism, the BJP refused to take corrective steps and persisted with the relatives,” said Congress spokesperson Gopal Tiwari"""
doc = nlp(text)

# %%
print("Named Entities:\n")
for ent in doc.ents:
    print(f"Entity: {ent.text} | Label: {ent.label_}")
# Out:
# Named Entities:
#
# Entity: BJP | Label: ORG
# Entity: five | Label: CARDINAL
# Entity: Loha | Label: GPE
# Entity: Nanded | Label: GPE
# Entity: Congress | Label: ORG
# Entity: Sunday | Label: DATE
# Entity: the saffron party’s | Label: ORG
# Entity: Bharatiya Janata Party | Label: ORG
# Entity: Gajanan Suryawanshi | Label: WORK_OF_ART
# Entity: Loha | Label: ORG
# Entity: Godavari | Label: PERSON
# Entity: Sachin Suryawanshi | Label: PERSON
# Entity: Supriya Suryavanshi | Label: FAC
# Entity: Yuvraj Waghmare | Label: PERSON
# Entity: Reena Vyavahare | Label: PERSON
# Entity: Loha | Label: ORG
# Entity: six | Label: CARDINAL
# Entity: Ashok Chavan | Label: PERSON
# Entity: BJP | Label: ORG
# Entity: BJP | Label: ORG
# Entity: BJP | Label: ORG
# Entity: BJP | Label: ORG
# Entity: BJP | Label: ORG
# Entity: Congress | Label: ORG
# Entity: Gopal Tiwari | Label: PERSON

# %%
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">After a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BJP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  leader and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     five
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  members of his family were defeated in the municipal council polls in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Loha
# ...

# %%
displacy.render(doc , style='dep', jupyter=True, options={'distance':80})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e9cb10d92dc046cc9f02de7b6bcd653c-0" class="displacy" width="15010" height="457.0" direction="ltr" style="max-width: none; height: 457.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">After</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
# ...

# %%
print("Sentences in the paragraph:\n")
for sent in doc.sents:
    print(sent.text)
# Out:
# Sentences in the paragraph:
#
# After a BJP leader and five members of his family were defeated in the municipal council polls in Loha town of Nanded, the Congress said Sunday that voters had given a befitting reply to the saffron party’s “parivarvad politics.”The
# Bharatiya Janata Party fielded Gajanan Suryawanshi for the Loha mayoral post.
# His wife, Godavari; brother Sachin Suryawanshi; sister-in-law Supriya Suryavanshi; brother-in-law Yuvraj Waghmare; and nephew’s wife Reena Vyavahare were fielded in different wards of Loha town.
# The defeat of the six is also being seen as a setback for former chief minister Ashok Chavan, who led the BJP’s campaign in the civic polls.
# The BJP refused to ask its candidates to withdraw from the fray despite criticism from the Maha Vikas Aghadi over its dynastic politics.
# “Voters have rejected the BJP’s nepotism.
# No matter who it fielded for campaigning, the voters did not care.
# They gave the BJP a taste of its own medicine.
# ...
